# %%
import numpy as np
import matplotlib.pyplot as plt
import bacco
# Out:
# /scratch/mzennaro/miniconda3/envs/mcnd/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
biases_vec = np.loadtxt('../scripts/biases_vec.txt')

# %%
indicesLH = np.array([10,29,37,40,70,85,127,158,165,184,208,220,240,254,267,274,293,305,336,374,375,388,433,444,
                      464,502,534,542,574,598,605,628,652,663,676,700,702,721,737,762,809,822,825,837,853,864,882,
                      899,901,911,939,948,950,951,964,976,977,1016,1022,1041,1050,1060,1082,1091,1103,1114,1147,
                      1157,1173,1175,1219,1222,1299,1309,1314,1317,1331,1365,1372,1378,1391,1397,1418,1444,1459,
                      1510,1512,1513,1515,1517,1533,1553,1567,1568,1599,1622,1642,1657,1659,1667])

fig, ax = plt.subplots(figsize=(8, 6))

for iLH in range(len(indicesLH)):
    for ib in range(len(biases_vec)):
        try:
            k, pk = np.loadtxt('../scripts/biased_pk_m2m_num_%04d_bias_num_%d.txt'%(indicesLH[iLH], ib), unpack=True)
        except:
            continue
        mask = pk > 0
        ax.loglog(k[mask], pk[mask], label='bias %d'%ib)
ax.set_xlabel(r'$k \,\, [h \,\, {\rm Mpc}^{-1}]$', fontsize=23)
ax.set_ylabel(r'$P(k) \,\, [h^{-3} \,\, {\rm Mpc}^3]$', fontsize=23)

plt.show()
